# %% [markdown]
# # Árvores de regressão - exercícios 01
#
# *Atenção! Devido descontinuação da base de imóveis boston os alunos devem utilizar a base de dados que se encontra em anexo.*
#
# A base que utilizaremos contem os dados dos imóveis da california.
# Considerem como variável Target (a ser prevista) a coluna median_house_value.
# O dataset é muito semelhante ao de boston, contendo localização, quartos, banheiros e outras variáveis interessantes para construção do modelo.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn import datasets
from sklearn.tree import DecisionTreeRegressor
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### 1. Certifique-se de que esta base está no formato adequado para o scikitlearn.
# ok, essa tarefa é tão fácil que você vai até desconfiar. Mas é preciso ter confiança sobre os dados que se usa ;)

# %%
df = pd.read_csv('housing.csv')
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
df = pd.get_dummies(df, columns = ['ocean_proximity'])

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
#Transformando em dados numéricos

df['ocean_proximity_<1H OCEAN'] = df['ocean_proximity_<1H OCEAN'].astype(int)
df['ocean_proximity_INLAND'] = df['ocean_proximity_INLAND'].astype(int)
df['ocean_proximity_ISLAND'] = df['ocean_proximity_ISLAND'].astype(int)
df['ocean_proximity_NEAR BAY'] = df['ocean_proximity_NEAR BAY'].astype(int)
df['ocean_proximity_NEAR OCEAN'] = df['ocean_proximity_NEAR OCEAN'].astype(int)

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %% [markdown]
# ### 2.  Visualize a matriz de correlação, e veja se aparentemente você encontra alguma variável com potencial preditivo interessante.

# %%
matriz_correlação = df.corr()

plt.figure(figsize=(12, 10))
sns.heatmap(matriz_correlação, 
           annot=True, 
            fmt=".2f", 
            cmap='coolwarm', 
            linewidths=0.5, #Coloca uma linha entre os elementos da matriz pra facilitar a visualização
            vmin=-1, vmax=1)
plt.title("Matriz de Correlação", fontsize=16)
plt.show()

# %% [markdown]
# Pelo o mapa de correlação a variável que mais se relaciona com a target (**median_house_value**) é a **median_income**, que se trata de uma renda.

# %% [markdown]
# ### 3. Separe os dados em validação e teste

# %%
X = df.drop('median_house_value', axis = 1)
y = df.median_house_value

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 50)

# %% [markdown]
# ### 4. Treine duas árvores, uma com profundidade máxima = 8, outra com profundidade máxima = 2.

# %%
arvore_regressora1 = DecisionTreeRegressor(max_depth = 8)
arvore_regressora2 = DecisionTreeRegressor(max_depth = 2)

arvore_regressora1.fit(X_train, y_train)
arvore_regressora2.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=2)

# %% [markdown]
# ### 5. Calcule o MSE de cada uma das árvores do item anterior para a base de treinamento e para a base de testes.

# %%
#retorna o coeficiente de determinação (R^2)
mse1 = arvore_regressora1.score(X_train, y_train)
mse2 = arvore_regressora2.score(X_train, y_train)

print(f'Score da arvore geradora 1 é: {mse1:.2f}')
print(f'Score da arvore geradora 2 é: {mse2:.2f}')
# Out:
# Score da arvore geradora 1 é: 0.76
# Score da arvore geradora 2 é: 0.50

# %%
# Predições das árvores para a base de treino e teste
y_pred_train_1 = arvore_regressora1.predict(X_train)
y_pred_train_2 = arvore_regressora2.predict(X_train)

y_pred_test_1 = arvore_regressora1.predict(X_test)
y_pred_test_2 = arvore_regressora2.predict(X_test)

# Calcular MSE para as árvores no conjunto de treino
mse_train_1 = mean_squared_error(y_train, y_pred_train_1)
mse_train_2 = mean_squared_error(y_train, y_pred_train_2)

# Calcular MSE para as árvores no conjunto de teste
mse_test_1 = mean_squared_error(y_test, y_pred_test_1)
mse_test_2 = mean_squared_error(y_test, y_pred_test_2)

print(f'O MSE da árvore geradora 1 na base de treino é: {mse_train_1:.2f}')
print(f'O MSE da árvore geradora 2 na base de treino é: {mse_train_2:.2f}')
print(f'O MSE da árvore geradora 1 na base de teste é: {mse_test_1:.2f}')
print(f'O MSE da árvore geradora 2 na base de teste é: {mse_test_2:.2f}')
# Out:
# O MSE da árvore geradora 1 na base de treino é: 3177056382.80
# O MSE da árvore geradora 2 na base de treino é: 6728231773.29
# O MSE da árvore geradora 1 na base de teste é: 4180483461.97
# O MSE da árvore geradora 2 na base de teste é: 6771276168.31

# %% [markdown]
# ### 6. Com base nos resultados do item anterior, qual árvore te parece mais adequada?

# %% [markdown]
# A árvore mais adequada é a árvore geradora 1, com 8 de profundidade, que o **coeficiente de determinação (R^2)** é a que mais se aproxima de 1.

# %% [markdown]
# ### 7. Faça uma visualização gráfica dessa árvore. Vamos discutir importância de variável mais adiante, mas veja a sua árvore, e pense um pouco: qual variável te parece mais "importante" na árvore?

# %%
plt.rc('figure', figsize = (30, 15))
tp = tree.plot_tree( arvore_regressora1,
                    feature_names = X.columns,
                    filled = True,
                    max_depth = 2) #2 para consguir vizualizar melhor a arvore

# %% [markdown]
# A variável que mais se parece importante se trata da **median_income** já que ela é a raiz da árvore e traz uma variação de valores maiores do que em comparação com a **ocean_proximity_INLAND**
